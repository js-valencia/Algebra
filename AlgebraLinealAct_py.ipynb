# %% [markdown]
# <a href="https://colab.research.google.com/github/js-valencia/Algebra/blob/main/AlgebraLinealAct_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade
# !pip install sympy
import sympy



from sympy import symbols, Eq, solve

# Definimos las variables
x, y = symbols('x y')

print("Resolviendo un sistema 2x2 con el MÉTODO DE SUSTITUCIÓN")
print("Forma general:")
print("a1*x + b1*y = c1")
print("a2*x + b2*y = c2")
print("-" * 50)

# Pedimos los coeficientes al usuario
a1, b1, c1 = map(float, input("Ingrese los coeficientes de la primera ecuación (a1 b1 c1): ").split())
a2, b2, c2 = map(float, input("Ingrese los coeficientes de la segunda ecuación (a2 b2 c2): ").split())

# Creamos las ecuaciones
ec1 = Eq(a1*x + b1*y, c1)
ec2 = Eq(a2*x + b2*y, c2)

print("\nEcuaciones ingresadas:")
print("E1:", ec1)
print("E2:", ec2)

# Paso 1: Despejar x de la primera ecuación
despeje_x = solve(ec1, x)[0]
print(f"\nPaso 1: Despejamos x de la primera ecuación:")
print(f"x = {despeje_x}")

# Paso 2: Sustituimos x en la segunda ecuación
print("\nPaso 2: Sustituimos x en la segunda ecuación:")
ec2_sust = ec2.subs(x, despeje_x)
print("Ecuación en y:", ec2_sust)

# Paso 3: Resolver para y
sol_y = solve(ec2_sust, y)[0]
print(f"\nPaso 3: Resolviendo para y obtenemos: y = {sol_y}")

# Paso 4: Sustituir y en la ecuación de x
sol_x = despeje_x.subs(y, sol_y)
print(f"\nPaso 4: Sustituyendo y en la ecuación despejada obtenemos: x = {sol_x}")

# Solución final
print("\n✅ Solución del sistema:")
print(f"x = {sol_x}, y = {sol_y}")
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy) (1.3.0)
# Resolviendo un sistema 2x2 con el MÉTODO DE SUSTITUCIÓN
# Forma general:
# a1*x + b1*y = c1
# a2*x + b2*y = c2
# --------------------------------------------------
# Ingrese los coeficientes de la primera ecuación (a1 b1 c1): 5 11 32
# Ingrese los coeficientes de la segunda ecuación (a2 b2 c2): -9 7 8
#
# Ecuaciones ingresadas:
# E1: Eq(5.0*x + 11.0*y, 32.0)
# E2: Eq(-9.0*x + 7.0*y, 8.0)
#
# Paso 1: Despejamos x de la primera ecuación:
# x = 6.4 - 2.2*y
#
# Paso 2: Sustituimos x en la segunda ecuación:
# Ecuación en y: Eq(26.8*y - 57.6, 8.0)
#
# Paso 3: Resolviendo para y obtenemos: y = 2.44776119402985
#
# Paso 4: Sustituyendo y en la ecuación despejada obtenemos: x = 1.01492537313433
#
# ✅ Solución del sistema:
# x = 1.01492537313433, y = 2.44776119402985

# %%
# !pip install --upgrade
# !pip install sympy
import sympy



from sympy import symbols, Eq, solve

# Definimos las variables
x, y = symbols('x y')

print("Resolviendo un sistema 2x2 con el MÉTODO DE SUSTITUCIÓN")
print("Forma general:")
print("a1*x + b1*y = c1")
print("a2*x + b2*y = c2")
print("-" * 50)

# Pedimos los coeficientes al usuario
a1, b1, c1 = map(float, input("Ingrese los coeficientes de la primera ecuación (a1 b1 c1): ").split())
a2, b2, c2 = map(float, input("Ingrese los coeficientes de la segunda ecuación (a2 b2 c2): ").split())

# Creamos las ecuaciones
ec1 = Eq(a1*x + b1*y, c1)
ec2 = Eq(a2*x + b2*y, c2)

print("\nEcuaciones ingresadas:")
print("E1:", ec1)
print("E2:", ec2)

# Paso 1: Despejar x de la primera ecuación
despeje_x = solve(ec1, x)[0]
print(f"\nPaso 1: Despejamos x de la primera ecuación:")
print(f"x = {despeje_x}")

# Paso 2: Sustituimos x en la segunda ecuación
print("\nPaso 2: Sustituimos x en la segunda ecuación:")
ec2_sust = ec2.subs(x, despeje_x)
print("Ecuación en y:", ec2_sust)

# Paso 3: Resolver para y
sol_y = solve(ec2_sust, y)[0]
print(f"\nPaso 3: Resolviendo para y obtenemos: y = {sol_y}")

# Paso 4: Sustituir y en la ecuación de x
sol_x = despeje_x.subs(y, sol_y)
print(f"\nPaso 4: Sustituyendo y en la ecuación despejada obtenemos: x = {sol_x}")

# Solución final
print("\n✅ Solución del sistema:")
print(f"x = {sol_x}, y = {sol_y}")
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy) (1.3.0)
# Resolviendo un sistema 2x2 con el MÉTODO DE SUSTITUCIÓN
# Forma general:
# a1*x + b1*y = c1
# a2*x + b2*y = c2
# --------------------------------------------------
# Ingrese los coeficientes de la primera ecuación (a1 b1 c1): 10 18 -11
# Ingrese los coeficientes de la segunda ecuación (a2 b2 c2): 16 -9 -5
#
# Ecuaciones ingresadas:
# E1: Eq(10.0*x + 18.0*y, -11.0)
# E2: Eq(16.0*x - 9.0*y, -5.0)
#
# Paso 1: Despejamos x de la primera ecuación:
# x = -1.8*y - 1.1
#
# Paso 2: Sustituimos x en la segunda ecuación:
# Ecuación en y: Eq(-37.8*y - 17.6, -5.0)
#
# Paso 3: Resolviendo para y obtenemos: y = -0.333333333333333
#
# Paso 4: Sustituyendo y en la ecuación despejada obtenemos: x = -0.500000000000000
#
# ✅ Solución del sistema:
# x = -0.500000000000000, y = -0.333333333333333

# %%
# !pip install --upgrade
# !pip install sympy
import sympy



from sympy import symbols, Eq, solve

# Definimos las variables
x, y = symbols('x y')

print("Resolviendo un sistema 2x2 con el MÉTODO DE SUSTITUCIÓN")
print("Forma general:")
print("a1*x + b1*y = c1")
print("a2*x + b2*y = c2")
print("-" * 50)

# Pedimos los coeficientes al usuario
a1, b1, c1 = map(float, input("Ingrese los coeficientes de la primera ecuación (a1 b1 c1): ").split())
a2, b2, c2 = map(float, input("Ingrese los coeficientes de la segunda ecuación (a2 b2 c2): ").split())

# Creamos las ecuaciones
ec1 = Eq(a1*x + b1*y, c1)
ec2 = Eq(a2*x + b2*y, c2)

print("\nEcuaciones ingresadas:")
print("E1:", ec1)
print("E2:", ec2)

# Paso 1: Despejar x de la primera ecuación
despeje_x = solve(ec1, x)[0]
print(f"\nPaso 1: Despejamos x de la primera ecuación:")
print(f"x = {despeje_x}")

# Paso 2: Sustituimos x en la segunda ecuación
print("\nPaso 2: Sustituimos x en la segunda ecuación:")
ec2_sust = ec2.subs(x, despeje_x)
print("Ecuación en y:", ec2_sust)

# Paso 3: Resolver para y
sol_y = solve(ec2_sust, y)[0]
print(f"\nPaso 3: Resolviendo para y obtenemos: y = {sol_y}")

# Paso 4: Sustituir y en la ecuación de x
sol_x = despeje_x.subs(y, sol_y)
print(f"\nPaso 4: Sustituyendo y en la ecuación despejada obtenemos: x = {sol_x}")

# Solución final
print("\n✅ Solución del sistema:")
print(f"x = {sol_x}, y = {sol_y}")
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy) (1.3.0)
# Resolviendo un sistema 2x2 con el MÉTODO DE SUSTITUCIÓN
# Forma general:
# a1*x + b1*y = c1
# a2*x + b2*y = c2
# --------------------------------------------------
# Ingrese los coeficientes de la primera ecuación (a1 b1 c1): 4 5 5
# Ingrese los coeficientes de la segunda ecuación (a2 b2 c2): -4 -10 -7
#
# Ecuaciones ingresadas:
# E1: Eq(4.0*x + 5.0*y, 5.0)
# E2: Eq(-4.0*x - 10.0*y, -7.0)
#
# Paso 1: Despejamos x de la primera ecuación:
# x = 1.25 - 1.25*y
#
# Paso 2: Sustituimos x en la segunda ecuación:
# Ecuación en y: Eq(-5.0*y - 5.0, -7.0)
#
# Paso 3: Resolviendo para y obtenemos: y = 0.400000000000000
#
# Paso 4: Sustituyendo y en la ecuación despejada obtenemos: x = 0.750000000000000
#
# ✅ Solución del sistema:
# x = 0.750000000000000, y = 0.400000000000000
